# %%
from langgraph.graph import StateGraph,START,END
from typing import TypedDict
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()
model = ChatGroq(model="llama-3.3-70b-versatile",temperature=0.1)

# %%
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state:BlogState)->BlogState:
    #fetch title
    title = state['title']

    #call llm gen outline
    prompt = f'Generate a outline for a blog on the topic - {title}'

    #update state
    state['outline']=model.invoke(prompt).content
    return state

# %%
def create_blog(state:BlogState)->BlogState:
    title = state['title']
    outline = state['outline']

    prompt = f'write a detailed blog on the title - {title} using the following outline - {outline}'

    state['content']=model.invoke(prompt).content
    return state

# %%
graph = StateGraph(BlogState)

#nodes
graph.add_node('create_outline',create_outline)
graph.add_node('create_blog',create_blog)

graph.add_edge(START,'create_outline')
graph.add_edge('create_outline','create_blog')
graph.add_edge('create_blog',END)

workflow = graph.compile()

# %%
final_state = workflow.invoke({'title':'Rise of ai in india'})
print(final_state)
# Out:
# {'title': 'Rise of ai in india', 'outline': 'Here\'s a suggested outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Context: India\'s emergence as a significant player in the global AI landscape\n* Thesis statement: India is witnessing a significant rise in AI adoption, driven by government initiatives, technological advancements, and a growing talent pool.\n\n**II. Current State of AI in India**\n\n* Overview of the current AI ecosystem in India, including:\n\t+ Key industries adopting AI (e.g., healthcare, finance, manufacturing)\n\t+ Notable AI startups and companies in India\n\t+ Government initiatives and policies supporting AI development (e.g., National AI Strategy, AI Task Force)\n* Statistics and trends: AI market size, growth rate, and job creation in India\n\n**III. Drivers of AI Growth in India**\n\n* **Government Support**:\n\t+ Initiatives like Digital India, Make in India, and Startup India\n\t+ Funding and incentives for AI research and development\n* **Technological Advancements**:\n\t+ Availability of computing power, data storage, and cloud infrastructure\n\t+ Advancements in machine learning, natural language processing, and computer vision\n* **Talent Pool**:\n\t+ Growing number of AI professionals and researchers in India\n\t+ Increasing focus on AI education and training programs\n\n**IV. Applications of AI in India**\n\n* **Industry-specific use cases**:\n\t+ Healthcare: medical diagnosis, patient care, and personalized medicine\n\t+ Finance: credit scoring, risk management, and customer service\n\t+ Manufacturing: predictive maintenance, quality control, and supply chain optimization\n* **Social Impact**:\n\t+ AI for social good: education, agriculture, and environmental sustainability\n\t+ AI-powered solutions for India\'s development challenges (e.g., poverty, healthcare, education)\n\n**V. Challenges and Opportunities**\n\n* **Challenges**:\n\t+ Data quality and availability\n\t+ Regulatory framework and ethics\n\t+ Job displacement and skill gap\n* **Opportunities**:\n\t+ Collaboration between industry, academia, and government\n\t+ Development of indigenous AI solutions for India\'s unique challenges\n\t+ Export of AI services and solutions to global markets\n\n**VI. Conclusion**\n\n* Recap of the rise of AI in India\n* Future outlook: India\'s potential to become a global AI leader\n* Call to action: Encouraging stakeholders to contribute to India\'s AI growth story\n\nThis outline should provide a good structure for your blog post on the rise of AI in India. Feel free to modify it as needed to suit your writing style and goals.', 'content': "**The Rise of AI in India: A New Era of Innovation and Growth**\n\nArtificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. As a country with a strong IT sector and a growing economy, India is emerging as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool. We will delve into the current state of AI in India, the drivers of AI growth, applications of AI, challenges, and opportunities, and conclude with a future outlook on India's potential to become a global AI leader.\n\n**Current State of AI in India**\n\nIndia's AI ecosystem is rapidly evolving, with key industries such as healthcare, finance, and manufacturing adopting AI solutions to improve efficiency, productivity, and customer experience. Notable AI startups and companies in India, such as Niki.ai, SigTuple, and Flipkart, are making significant contributions to the development of AI-powered products and services. The government has also launched initiatives like the National AI Strategy and the AI Task Force to support AI development and create a conducive environment for in ...

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: A New Era of Innovation and Growth**
#
# Artificial Intelligence (AI) has been making waves globally, transforming industries and revolutionizing the way we live and work. As a country with a strong IT sector and a growing economy, India is emerging as a significant player in the global AI landscape. In this blog, we will explore the rise of AI in India, driven by government initiatives, technological advancements, and a growing talent pool. We will delve into the current state of AI in India, the drivers of AI growth, applications of AI, challenges, and opportunities, and conclude with a future outlook on India's potential to become a global AI leader.
#
# **Current State of AI in India**
#
# India's AI ecosystem is rapidly evolving, with key industries such as healthcare, finance, and manufacturing adopting AI solutions to improve efficiency, productivity, and customer experience. Notable AI startups and companies in India, such as Niki.ai, SigTuple, and Flipkart, are making significant contributions to the development of AI-powered products and services. The government has also launched initiatives like the National AI Strategy and the AI Task Force to support AI development and create a conducive environment for innovation.
#
# According to a report by Nasscom, the AI market in India is expected to reach $7.8 billion by 2025, growing at a CAGR of 30.8%. The report also highlights that the AI industry in India has created over 100,000 jobs in the past few years, with a significant increase in demand for AI professionals. The Indian government has also launched several initiatives to promote AI adoption, including the Digital India program, which aims to transform India into a digitally empowered society.
#
# **Drivers of AI Growth in India**
#
# The growth of AI in India can be attributed to several factors, including government support, technological advancements, and a growing talent pool.
#
# * **Government Support**: The Indian government has launched several initiatives to support AI development, including the Digital India program, Make in India, and Startup India. These initiatives provide funding, incentives, and infrastructure support to AI startups and companies. For example, the government has established the National AI Mission, which aims to develop a robust AI ecosystem in India.
# * **Technological Advancements**: The availability of computing power, data storage, and cloud infrastructure has made it possible for companies to develop and deploy AI solutions. Advancements in machine learning, natural language processing, and computer vision have also enabled the development of more sophisticated AI applications. For instance, the development of deep learning algorithms has enabled companies to build more accurate image recognition systems.
# * **Talent Pool**: India has a growing number of AI professionals and researchers, with many universities and institutions offering AI-related courses and programs. The increasing focus on AI education and training programs has also helped to bridge the skill gap in the industry. For example, the Indian Institute of Technology (IIT) has launched several AI-related courses, including a master's program in AI and machine learning.
#
# **Applications of AI in India**
#
# AI has a wide range of applications in India, across various industries and sectors.
#
# * **Industry-specific use cases**: AI is being used in healthcare for medical diagnosis, patient care, and personalized medicine. In finance, AI is being used for credit scoring, risk management, and customer service. In manufacturing, AI is being used for predictive maintenance, quality control, and supply chain optimization. For example, the Indian healthcare company, Apollo Hospitals, has developed an AI-powered system for diagnosing diseases.
# * **Social Impact**: AI is being used for social good, including education, agriculture, and environmental sustainability. AI-powered solutions are also being developed to address India's development challenges, such as poverty, healthcare, and education. For instance, the Indian government has launched an AI-powered platform to provide education to underprivileged children.
#
# **Challenges and Opportunities**
#
# While AI has the potential to transform India's economy and society, there are several challenges that need to be addressed.
#
# * **Challenges**: Data quality and availability are significant challenges in India, with many organizations struggling to access high-quality data. Regulatory frameworks and ethics are also important considerations, with the need for clear guidelines on AI development and deployment. Job displacement and skill gap are also concerns, with the need for retraining and upskilling programs to prepare workers for an AI-driven economy. For example, the Indian government has launched a program to retrain workers in the manufacturing sector who have been displaced by automation.
# * **Opportunities**: Collaboration between industry, academia, and government is essential for driving AI growth in India. The development of indigenous AI solutions for India's unique challenges is also an opportunity, with the potential for Indian companies to develop innovative solutions that can be exported to global markets. For instance, the Indian company, Tata Consultancy Services (TCS), has developed an AI-powered platform for managing supply chains.
#
# **Conclusion**
#
# In conclusion, the rise of AI in India is a significant trend that has the potential to transform the country's economy and society. With government support, technological advancements, and a growing talent pool, India is well-positioned to become a global AI leader. However, there are challenges that need to be addressed, including data quality, regulatory frameworks, and job displacement. By leveraging the opportunities presented by AI, India can drive growth, innovation, and social impact, and become a leader in the global AI landscape. We encourage stakeholders to contribute to India's AI growth story and help shape the country's future as a hub for AI innovation and development.
#
# As we look to the future, it is clear that AI will play a critical role in shaping India's economy and society. With the right policies, investments, and partnerships, India can unlock the full potential of AI and become a global leader in this field. We believe that the rise of AI in India is a story that is still unfolding, and we are excited to see the impact that it will have on the country and the world.
